# %%
# https://larryriddle.agnesscott.org/ColabTurtlePlus/documentation.html
# !pip3 install ColabTurtlePlus

# %%
#https://github.com/tolgaatam/ColabTurtle
# !pip3 install ColabTurtle
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for ColabTurtle: filename=ColabTurtle-2.1.0-py3-none-any.whl size=7642 sha256=d3489949c7af0c902cbf2713de898e3310f8d125a7339fa32e9256460d6a5b35
#   Stored in directory: /root/.cache/pip/wheels/f6/9e/81/137e7da25129474562d30f8660be599e5c8d79228cb747e5b9
# Successfully built ColabTurtle
# ...

# %%
# Drawing Star ⭐
import ColabTurtle.Turtle as star
star.initializeTurtle()
star.right(75)
star.forward(200)

for i in range(4):
    star.right(144)
    star.forward(200)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="593.185" y2="198.236" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="593.185" y1="198.236" x2="467.321" y2="353.665" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="467.321" y1="353.665" x2="477.788" y2="153.939" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="477.788" y1="153.939" x2="586.716" y2="321.673" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="586.716" y1="321.673" x2="400.0" y2="249.999" stroke-linecap="round" style="stroke:white;stroke-width:4"/>
#         <g visibility=visible transform="rotate(291,400.0,249.999) translate(382.0, 231.999)">
# ...

# %%
import ColabTurtle.Turtle as turtle

turtle.initializeTurtle()
turtle.bgcolor(255, 255, 255)
turtle.shape('circle')
turtle.color('green')
turtle.speed(10)
for i in range(90):
  turtle.forward(4)
  turtle.right(4)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="rgb(255,255,255)"/>
# ...

# %%
import ColabTurtlePlus.Turtle as turtle
turtle.clearscreen()
turtle.circle(50, 360)
# Out:
#       <svg width="800" height="600">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
#         <path d="M 400.0 300.0 A 50 50 0 0 0 412.941 298.296" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 412.941 298.296 A 50 50 0 0 0 425.0 293.301" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 425.0 293.301 A 50 50 0 0 0 435.355 285.355" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 435.355 285.355 A 50 50 0 0 0 443.301 275.0" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 443.301 275.0 A 50 50 0 0 0 448.296 262.941" stroke-linecap="round"
# ...

# %%
# Drawing dotted lines
turtle.initializeTurtle()
turtle.bgcolor(255, 255, 255)
turtle.shape('circle')
turtle.color('green')
turtle.right(90)
for i in range(20):
  if i%2 == 0:
    turtle.pendown()
    turtle.forward(10)
  else:
    turtle.penup()
    turtle.forward(10)

turtle.hideturtle()
# Out:
#       <svg width="800" height="600">
#         <rect width="100%" height="100%" style="fill:rgb(255,255,255);stroke:;stroke-width:1"/>
#
#
# ...

# %%
# Drawing multiple shapes
import random
import ColabTurtle.Turtle as turtle
turtle.initializeTurtle()
turtle.bgcolor(255, 255, 255)
turtle.color('red')
turtle.hideturtle()
turtle.right(270)
turtle.pensize(2)

colors = ["MediumSpringGreen", "Gold", "OrangeRed", "MediumVioletRed", "MediumPurple", "LawnGreen", "DodgerBlue", "Coral"]

def draw_shape(sides):
  angle = 360 / sides
  for _ in range(sides):
    turtle.forward(75)
    turtle.right(angle)


for i in range(3, 11):
  turtle.color(random.choice(colors))
  draw_shape(i)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="rgb(255,255,255)"/>
# ...

# %%
#Random path
import ColabTurtle.Turtle as turtle
turtle.initializeTurtle()
turtle.speed(6)
turtle.pensize(20)
turtle.shape('circle')
turtle.bgcolor(255, 255, 255)
direction = [0, 90, 180, 270]
for i in range(50):
  turtle.color(random.choice(colors))
  turtle.forward(75)
  turtle.right(random.choice(direction))
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="rgb(255,255,255)"/>
# ...

# %%
# Spirograph
import random

def color():
  r = random.randint(0, 255)
  g = random.randint(0, 255)
  b = random.randint(0, 255)
  color = (r, g, b)
  return color

import ColabTurtle.Turtle as turtle

turtle.initializeTurtle()
turtle.pensize(1)
turtle.hideturtle()
turtle.bgcolor(255, 255, 255)
turtle.speed(13)

def polygon(length, n):
    for _ in range(n):
        turtle.forward(length)
        turtle.left(360 / n)

def spiro(num):
  for i in range(int(360/num)):
    turtle.color(color())
    current_heading = turtle.heading()
    turtle.setheading(current_heading + 10)
    polygon(10, 60)

spiro(5)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="rgb(255,255,255)"/>
# ...

# %%
# Spirograph
import random

def color():
  r = random.randint(0, 255)
  g = random.randint(0, 255)
  b = random.randint(0, 255)
  color = (r, g, b)
  return color

import ColabTurtle.Turtle as turtle

turtle.initializeTurtle()
turtle.pensize(1)
turtle.hideturtle()
#turtle.bgcolor(255, 255, 255)
turtle.speed(13)

def polygon(length, n):
    for _ in range(n):
        turtle.forward(length)
        turtle.left(360 / n)

def spiro(num):
  for i in range(int(360/num)):
    turtle.color(color())
    current_heading = turtle.heading()
    turtle.setheading(current_heading + 10)
    turtle.forward(10)
    polygon(10, 50)

spiro(7)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
# ...

# %%
# https://pypi.org/project/colorgram.py/
# !pip install colorgram.py

# %%
# For importing colors from an Spot drawing image
import colorgram
dot_color = []
# 8 * 6 = 48
colors = colorgram.extract('/content/images.jpg', 48)

for color in colors:
  dot_color.append((color.rgb.r, color.rgb.g, color.rgb.b))

print(dot_color)
print(len(dot_color))
# Out:
# 35
# [(252, 249, 241), (254, 247, 252), (242, 252, 249), (247, 250, 253), (38, 95, 177), (229, 162, 89), (238, 223, 95), (218, 69, 103), (116, 186, 225), (193, 69, 25), (230, 120, 152), (241, 64, 35), (179, 49, 88), (141, 229, 210), (85, 202, 165), (59, 40, 14), (246, 148, 176), (170, 177, 231), (74, 185, 106), (173, 24, 11), (247, 222, 1), (22, 34, 79), (23, 151, 52), (128, 33, 42), (118, 215, 241), (241, 161, 7), (95, 100, 195), (17, 155, 226), (29, 59, 121), (77, 30, 37), (247, 160, 151), (254, 9, 2), (251, 8, 21), (71, 70, 40), (2, 6, 0)]
# 35

# %%
# making the list of valid colors

color_list = [(38, 95, 177), (229, 162, 89), (238, 223, 95), (218, 69, 103), (116, 186, 225), (193, 69, 25), (230, 120, 152), (241, 64, 35), (179, 49, 88), (141, 229, 210), (85, 202, 165), (59, 40, 14), (246, 148, 176), (170, 177, 231), (74, 185, 106), (173, 24, 11), (247, 222, 1), (22, 34, 79), (23, 151, 52), (128, 33, 42), (118, 215, 241), (241, 161, 7), (95, 100, 195), (17, 155, 226), (29, 59, 121), (77, 30, 37), (247, 160, 151), (254, 9, 2), (251, 8, 21), (71, 70, 40)]

print(len(color_list))
# Out:
# 30

# %%
from ctypes import sizeof
import ColabTurtlePlus.Turtle as turtle
import random

turtle.initializeTurtle(window=(510,510))
turtle.penup()
turtle.shape('circle')
turtle.setheading(135)
turtle.forward(325)
turtle.setheading(0)
turtle.speed(13)


def dot(size, color):
  turtle.pendown()
  turtle.color(color)
  turtle.pensize(size)
  turtle.forward(1)
  turtle.penup()

for num in range(1, 100):
  dot(20, random.choice(color_list))
  turtle.forward(50)

  if num % 10 == 0:
    turtle.setheading(270)
    turtle.forward(50)
    turtle.setheading(180)
    turtle.forward(510)
    turtle.setheading(0)
# Out:
#       <svg width="500" height="510">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
# ...

# %%
import ColabTurtlePlus.Turtle as turtle
import random

y_position = [-100, -50, 0, 50, 100, 150]
turtle_color = ["red", "green", "violet", "brown", "blue", "orange"]
all_turtle = []
turtle.clearscreen()
turtle.initializeTurtle(window=(500,500))


for turtle_index in range(0, 6):
    tu = turtle.Turtle()
    tu.shape("turtle")
    tu.color(turtle_color[turtle_index])
    tu.penup()
    tu.goto(x= -230, y = y_position[turtle_index])
    all_turtle.append(tu)

user_bet = input("Which color Turtle will win the Race:\n")

if user_bet:
    game_on = True

while game_on:
    for turt in all_turtle:
        if turt.xcor() > 230:
            if user_bet == turt.pencolor():
                print(f"You Won!, The {turt.pencolor()} turtle has won the race.")
            else:
                print(f"You Lost!, The {turt.pencolor()} turtle has won the race.")
            game_on = False

        rand_dist = random.randint(20, 30)
        turt.forward(rand_dist)
# Out:
# Put clearscreen() as the first line in a cell (after the import command) to re-run turtle commands in the cell
#       <svg width="500" height="500">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
#
#
#
#         <g id="turtle" visibility="visible" transform="rotate(90,472.0,350.0) translate(472.0, 350.0)">
# ...

# %%
1
